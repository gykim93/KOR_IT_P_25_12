# %%
import pandas as pd
import numpy as np

# %%
# 실습 데이터 생성
data = {
    '이름' : ['철수', '영희', '민수', '지영', '동수'],
    '학년' : [1, 2, 1, 3, 2],
    '성별' : ['남', '여', '남', '여', '남'],
    '국어' : [90, 80, 85, 95, np.nan], # np.nan => 결측치(데이터 없음)
    '영어' : [85, 90, 80, 95, 70],
    '수학' : [100, 88, 92, 85, 60]
}
df = pd.DataFrame(data)
df.to_csv('students.csv', index=False)
print("실습 데이터 생성!")
# Out:
# 10
